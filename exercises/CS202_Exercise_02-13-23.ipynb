# %% [markdown]
# # CS202: Compiler Construction
#
# ## In-class Exercises, Week of 02/13/2023
#
# ----

# %% [markdown]
# # Interference Graph
#
# The second part of the allocate-registers pass will build an *interference graph* using the live-after sets computed earlier. The interference graph is an undirected graph with a node for each program variable, and an edge between each pair of variables which may *not* share a home.

# %% [markdown]
# ## Question 1
#
# What variables in the this graph can share a register? What variables can't?
#
#
# ```
#   r
#   |
#   c - t
#  / \/
# a - b
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 2
#
# Describe the build-interference part of the allocate-registers pass.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----

# %% [markdown]
# # Graph Coloring

# %% [markdown]
# ## Question 3
#
# Assign registers from the set `r8`, `r9`, `r10` to the variables `a`, `b`, and `c`, consistent with the interference graph below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 4
#
# Use the saturation-based graph coloring algorithm described in the textbook to color the interference graph below. Fill in the steps of the algorithm in the table. In the last 4 columns, fill in the saturation sets for each variable *after* the selection of the color for that step.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 5
#
# Describe the saturation-based graph coloring algorithm.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 6
#
# Use the saturation-based graph coloring algorithm described in the textbook to color the interference graph below. Fill in the steps of the algorithm in the table. In the last 4 columns, fill in the saturation sets for each variable after the selection of the color for that step.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 7
#
# Using the coloring from above, assign registers from the set `r8`, `r9`, `r10` to each variable.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 8
#
# Using the coloring from above, assign locations to each variable. Use the register `r8`, and place *spilled* variables on the stack.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 9
#
# Describe the `allocate-registers` pass.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----
# # Conditionals

# %% [markdown]
# ## Question 10
#
# The following grammar defines the *concrete syntax* for a subset of $L_{if}$.
#
# \begin{align*}
# b &::= \texttt{True} \mid \texttt{False}\\
# cmp &::= \texttt{==} \mid \texttt{!=} \mid \texttt{<} \mid \texttt{<=} \mid \texttt{>} \mid \texttt{>=} \\
# exp &::= n \mid b \mid exp + exp \mid exp\; cmp\; exp \mid exp\; \texttt{and}\; exp \mid exp\; \texttt{or}\; exp \\
# stmt &::= var = exp \mid \texttt{print}(exp) \mid \texttt{if}\; exp: stmt^+\; \texttt{else}: stmt^+ \\
# \end{align*}
#
# Write a program that prints 42 if 5 equals 6, and 0 otherwise.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 11
#
# Write the same program in x86 assembly language.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 12
#
# Convert the following program to pseudo-x86 assembly:
#
# ```
# if 5 == 6:
#   x = 0
# else:
#   x = 40
# print(x+2)
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 13
#
# Describe a strategy for converting `if` expressions into x86 assembly.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# **Notes:**
# - `if` is a structure for *control flow*
# - A [control flow graph](https://en.wikipedia.org/wiki/Control-flow_graph) can express x86 programs with control flow
