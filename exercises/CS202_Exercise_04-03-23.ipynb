# %% [markdown]
# # CS202: Compiler Construction
#
# ## In-class Exercises, Week of 04/03/2023
#
# ----

# %% [markdown]
# # Select Instructions

# %% [markdown]
# ## Question 1
#
# Write x86 instructions corresponding to the output of `select-instructions` on the following `assign` statement:
#
# ```
# Assign("x", Prim('allocate', [Constant(24)]))
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 2
#
# Write x86 instructions corresponding to the output of `select-instructions` on the following statement:
#
# ```
# Assign('_', Prim('collect', [Constant(16)]))
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 3
#
# Write x86 instructions corresponding to the output of `select-instructions` on the following statements:
#
# a. `Assign('y', Prim('subscript', [Var('x'), Constant(0)]))`
#
# b. `Assign('_', Prim('tuple_set', [Var('x'), Constant(0), Constant(1)]))`

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----
# # Structure of the Heap and Garbage Collection

# %% [markdown]
# ## Question 4
#
# Write the tag, in binary and decimal, for the vectors referenced by `x`, `y`, and `z` in Question 2. Reference section 6.2.3 (and Figure 6.8) in the textbook.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 5
#
# What is the purpose of the tag?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 6
#
# Write code to construct the 3 tags above. Use Python's `<<` operator for arithmetic shifting.

# %%
YOUR ANSWER HERE
# Out:
# x tag: 5
# y tag: 261
# z tag: 389

# %% [markdown]
# ## Question 7
#
# Imagine execution of a program has produced the following heap. Perform garbage collection, drawing the To Space on your own paper.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Draw your solution on your own paper**

# %% [markdown]
# ----

# %% [markdown]
# # Register allocation

# %% [markdown]
# ## Question 8
#
# Why do we need to ensure that tupled-valued variables are spilled when we call the collector? How can we accomplish this?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 9
#
# How can we modify register allocation to ensure that tuple-valued variables get spilled to the root stack, and non-tuple-valued variables get spilled to the regular stack?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----
# # Patch instructions

# %% [markdown]
# ## Question 10
#
# Describe the changes to the `patch-instructions` pass.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ----
# # Prelude and conclusion

# %% [markdown]
# ## Question 11
#
# Write x86 assembly for the `main` block of the program:
#
# ```
# x = (1,)
# y = (2,)
# z = x[0]
# ```

# %% [markdown]
# YOUR ANSWER HERE
